# %% [markdown]
# pscratch/sd/a/arosado/mocks_tests/3dbox/3dbox_nmesh512_L5274.0_bias1.0_seed42

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
from nbodykit import style, setup_logging

import matplotlib.pyplot as plt
plt.style.use(style.notebook)

# %%
setup_logging() # turn on logging to screen

# %%
from nbodykit.lab import FFTPower
import nbodykit as nb
#import nbodykit.io.bigfile as bf
from nbodykit.source.catalog import BigFileCatalog
import numpy
# Out:
# [ 000000.96 ]   0: 03-28 14:57  numexpr.utils   INFO     Note: detected 256 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# [ 000000.96 ]   0: 03-28 14:57  numexpr.utils   INFO     Note: NumExpr detected 256 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.

# %%
def read_BigFile(filename):
    FILE = bf.BigFile(filename, header='Header')
    n    = FILE.size
    pos  = FILE.read('Position', 0, n)
    return nb.ArrayCatalog(pos)
#cat = read_BigFile(fn)

# %%
fn = "/pscratch/sd/a/arosado/mocks_tests/3dbox/3dbox_nmesh512_L5274.0_bias1.0_seed42"
cat = BigFileCatalog(fn, header='Header')

BIAS = 1.
BOX   = 5274
NMESH = 512

mesh = cat.to_mesh(compensated=True, window='cic', position='Position', BoxSize=BOX, Nmesh=NMESH)
rpol = FFTPower(mesh, mode='1d', kmin=0.0, poles=[0,2,4])
p = rpol.power
# Out:
# [ 000339.78 ]   0: 03-28 15:02  CatalogSource   INFO     Extra arguments to FileType: () {'header': 'Header'}
# /tmp/ipykernel_213367/860721469.py:8: DeprecationWarning: The window argument is deprecated. Use `resampler=` instead
#   mesh = cat.to_mesh(compensated=True, window='cic', position='Position', BoxSize=BOX, Nmesh=NMESH)
# [ 000339.94 ]   0: 03-28 15:02  CatalogMesh     INFO     Chunk 0 ~ 4194304 / 28553773
# [ 000341.38 ]   0: 03-28 15:02  CatalogMesh     INFO     painted 4194304 out of 28553773 objects to mesh
# [ 000341.38 ]   0: 03-28 15:02  CatalogMesh     INFO     Chunk 4194304 ~ 8388608 / 28553773
# [ 000342.87 ]   0: 03-28 15:02  CatalogMesh     INFO     painted 8388608 out of 28553773 objects to mesh
# [ 000342.87 ]   0: 03-28 15:02  CatalogMesh     INFO     Chunk 8388608 ~ 12582912 / 28553773
# [ 000344.57 ]   0: 03-28 15:03  CatalogMesh     INFO     painted 12582912 out of 28553773 objects to mesh
# [ 000344.57 ]   0: 03-28 15:03  CatalogMesh     INFO     Chunk 12582912 ~ 16777216 / 28553773
# [ 000346.24 ]   0: 03-28 15:03  CatalogMesh     INFO     painted 16777216 out of 28553773 objects to mesh
# [ 000346.24 ]   0: 03-28 15:03  CatalogMesh     INFO     Chunk 16777216 ~ 20971520 / 28553773
# [ 000348.04 ]   0: 03-28 15:03  CatalogMesh     INFO     painted 20971520 out of 28553773 objects to mesh
# [ 000348.04 ]   0: 03-28 15:03  CatalogMesh     INFO     Chunk 20971520 ~ 25165824 / 28553773
# [ 000349.57 ]   0: 03-28 15:03  CatalogMesh     INFO     painted 25165824 out of 28553773 objects to mesh
# [ 000349.57 ]   0: 03-28 15:03  CatalogMesh     INFO     Chunk 25165824 ~ 29360128 / 28553773
# [ 000350.95 ]   0: 03-28 15:03  CatalogMesh     INFO     painted 28553773 out of 28553773 objects to mesh
# [ 000350.99 ]   0: 03-28 15:03  CatalogMesh     INFO     painted 28553773 out of 28553773 objects to mesh
# [ 000350.99 ]   0: 03-28 15:03  CatalogMesh     INFO     mean particles per cell is 0.212742
# [ 000350.99 ]   0: 03-28 15:03  CatalogMesh     INFO     sum is 2.85538e+07
# [ 000351.14 ]   0: 03-28 15:03  CatalogMesh     INFO     normalized the convention to 1 + delta
# [ 000353.32 ]   0: 03-28 15:03  CatalogMesh     INFO     field: (BigFileCatalog(size=28553773, FileStack(BigFile(path=/pscratch/sd/a/arosado/mocks_tests/3dbox/3dbox_nmesh512_L5274.0_bias1.0_seed42, dataset=./, ncolumns=2, shape=(28553773,)>, ... 1 files)) as CatalogMesh) painting done

# %%
# plot each mu bin
Pk = p
#label = r'$\mu$=%.1f' %pkmu.coords['mu'][0]
plt.loglog(Pk['k'], Pk['power'].real - Pk.attrs['shotnoise'])#, label=label)

# plot the biased linear power spectrum
k = numpy.logspace(-2, 0, NMESH)
plt.loglog(k, b1**2 * Plin(k), c='k', label=r'$b_1^2 P_\mathrm{lin}$')

# add a legend and axes labels
plt.legend(loc=0, ncol=2, fontsize=16)
plt.xlabel(r"$k$ [$h \mathrm{Mpc}^{-1}$]")
plt.ylabel(r"$P(k, \mu)$ [$h^{-3} \mathrm{Mpc}^3$]")
plt.xlim(0.01, 0.4)
plt.ylim(100, 2e4)
# Out:
# (100, 20000.0)

# %%
b1 = BIAS
redshift = 0.85 

cosmo = nb.cosmology.Planck15
Plin = nb.cosmology.LinearPower(cosmo, redshift, transfer='CLASS')

# %%
# compute the 2d P(k,mu) power, with 5 mu bins
r = FFTPower(mesh, mode='2d', Nmu=5)
pkmu = r.power
# Out:
# [ 000093.10 ]   0: 03-28 14:58  CatalogMesh     INFO     Chunk 0 ~ 4194304 / 28553773
# [ 000094.30 ]   0: 03-28 14:58  CatalogMesh     INFO     painted 4194304 out of 28553773 objects to mesh
# [ 000094.30 ]   0: 03-28 14:58  CatalogMesh     INFO     Chunk 4194304 ~ 8388608 / 28553773
# [ 000095.48 ]   0: 03-28 14:58  CatalogMesh     INFO     painted 8388608 out of 28553773 objects to mesh
# [ 000095.48 ]   0: 03-28 14:58  CatalogMesh     INFO     Chunk 8388608 ~ 12582912 / 28553773
# [ 000096.67 ]   0: 03-28 14:58  CatalogMesh     INFO     painted 12582912 out of 28553773 objects to mesh
# [ 000096.67 ]   0: 03-28 14:58  CatalogMesh     INFO     Chunk 12582912 ~ 16777216 / 28553773
# [ 000097.86 ]   0: 03-28 14:58  CatalogMesh     INFO     painted 16777216 out of 28553773 objects to mesh
# [ 000097.86 ]   0: 03-28 14:58  CatalogMesh     INFO     Chunk 16777216 ~ 20971520 / 28553773
# [ 000099.05 ]   0: 03-28 14:58  CatalogMesh     INFO     painted 20971520 out of 28553773 objects to mesh
# [ 000099.05 ]   0: 03-28 14:58  CatalogMesh     INFO     Chunk 20971520 ~ 25165824 / 28553773
# [ 000100.24 ]   0: 03-28 14:58  CatalogMesh     INFO     painted 25165824 out of 28553773 objects to mesh
# [ 000100.24 ]   0: 03-28 14:58  CatalogMesh     INFO     Chunk 25165824 ~ 29360128 / 28553773
# [ 000101.17 ]   0: 03-28 14:58  CatalogMesh     INFO     painted 28553773 out of 28553773 objects to mesh
# [ 000101.21 ]   0: 03-28 14:58  CatalogMesh     INFO     painted 28553773 out of 28553773 objects to mesh
# [ 000101.21 ]   0: 03-28 14:58  CatalogMesh     INFO     mean particles per cell is 0.212742
# [ 000101.21 ]   0: 03-28 14:58  CatalogMesh     INFO     sum is 2.85538e+07
# [ 000101.30 ]   0: 03-28 14:58  CatalogMesh     INFO     normalized the convention to 1 + delta
# [ 000102.66 ]   0: 03-28 14:58  CatalogMesh     INFO     field: (BigFileCatalog(size=28553773, FileStack(BigFile(path=/pscratch/sd/a/arosado/mocks_tests/3dbox/3dbox_nmesh512_L5274.0_bias1.0_seed42, dataset=./, ncolumns=2, shape=(28553773,)>, ... 1 files)) as CatalogMesh) painting done

# %%
# plot each mu bin
for i in range(pkmu.shape[1]):
    Pk = pkmu[:,i]
    label = r'$\mu$=%.1f' %pkmu.coords['mu'][i]
    plt.loglog(Pk['k'], Pk['power'].real - Pk.attrs['shotnoise'], label=label)

# plot the biased linear power spectrum
k = numpy.logspace(-2, 0, 512)
plt.loglog(k, b1**2 * Plin(k), c='k', label=r'$b_1^2 P_\mathrm{lin}$')

# add a legend and axes labels
plt.legend(loc=0, ncol=2, fontsize=16)
plt.xlabel(r"$k$ [$h \mathrm{Mpc}^{-1}$]")
plt.ylabel(r"$P(k, \mu)$ [$h^{-3} \mathrm{Mpc}^3$]")
plt.xlim(0.01, 0.4)
plt.ylim(100, 2e4)
# Out:
# (100, 20000.0)

# %%
n = cat.size
pos = cat.read(['Position'])
pos[0]
# Out:
# dask.array<array, shape=(28553773, 3), dtype=float32, chunksize=(100000, 3), chunktype=numpy.ndarray>
